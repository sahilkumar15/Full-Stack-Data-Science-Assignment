# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### Questions:

# %%
import docx2txt
my_text = docx2txt.process("Assignment_1.docx")
print(my_text)
# Out:
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *
#
# 'hello'
#
# -87.8
#
# -
#
# /
#
#
#
# 6
#
#
#
# 2. What is the difference between string and variable?
#
#
#
# 3. Describe three different data types.
#
#
#
# 4. What is an expression made up of? What do all expressions do?
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
#
# bacon + 1
#
#
#
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam'
#
# 'spam' * 3
#
#
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# 10. Why does this expression cause an error? How can you fix it?
#
# ...

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
# Image(url= "http://my_site.com/my_picture.jpg")

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer:

# %% [markdown]
# Values are : **'hello', -87.8, 6** <br>
# Expression are : *, -, /, +

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer:

# %% [markdown]
# **Variable** is a ***store information*** and a **String** is a ***type of information*** that you would store in a Variable.<br>
# **String** is enclosed by **single quote, double quote**  and **triple quote.**<br>
# **Example: X = "Sahil Kumar"** where "Sahil Kumar" is a String and x is a variable.<br>

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In Python, numeric data type represents the data which has numeric value. Numeric value can be integer, float, complex numbers. These values are defined as int, float and complex class in Python.
#
# - **Integers**: This value is represented by int class. It contains positive and negative natural numbers.<br>
# Ex: 2, 4, -9.<br><br>
# - **Float**: This value is represented by float class. It is a real number with floating point representation. It is specified by decimal point.<br>
# Ex: 3.45, -9.67, 0.09<br><br>
# - **Complex:** This value is represented by complex class. It is specified as a (real part)+(imaginary part)j.<br>
# Ex: 4+8j, 9-7j

# %% [markdown]
# **Note – type()** function is used to determine the type of data type.

# %%
# Python program to 
# demonstrate numeric value 

a = 5
print("Type of a: ", type(a)) 

b = 5.0
print("\nType of b: ", type(b)) 

c = 2 + 4j
print("\nType of c: ", type(c))

# %% [markdown]
# #### Sequence type

# %% [markdown]
# **String:** In python, Strings are array of bytes representing Unicode characters. A String is a one or more characters put in a single quote, double-quote or triple quote. It is represented by str class.<br>
# Ex: "Hello Sahil"

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# **An Expression** is a construct made up of variables, operators, and method invocations, which are constructed according to the syntax of the language, that evaluates to a single value. As you can see from the other expressions, an expression can return other types of values as well, such as boolean or String .
#
#
# **An Expression** is a combination of values, variables, operators, and calls to functions. Expression need to be ***evaluated***. It is always evaluated down to single value.<br><br>

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# If you can print it, or assign it to a variable, it’s an **Expression**. If you can’t, it’s a **Statement**.<br><br>
# **Examples** of ***Expression:***<br>
# - 2 + 2
# - 3 * 7
# - max(3, 94)
# - round(81.5)
# - "foo"
# - False
# - 2<br>
# All of the above can be printed or assigned to a variable.<br><br>

# %% [markdown]
# Here are some **Examples** of **Statement**:<br>
# - if CONDITION:
# - elif CONDITION:
# - else:
# - for VARIABLE in SEQUENCE:
# - while CONDITION:
# - try:
# - except EXCEPTION as e:
# - class MYCLASS:
# - def MYFUNCTION():
# - return SOMETHING <br>
#
# None of the above constructs can be assigned to a variable.In other words, these constructs don’t “evaluate” to anything.

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# The variable bocon contains is **23.**

# %%
bacon =22
bacon+1
# Out:
# 23

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# 'spam'+'spamspam' = 'spamspamspam'<br>
# 'spam'*3 = 'spamspamspam'

# %%
'spam'+'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam'*3
# Out:
# 'spamspamspam'

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
#  Variable names cannot begin with a number. The int(), float(), and str() functions will evaluate to the integer, floating-point number, and string versions of the value passed to them.
# <br>
# 100 is a interger value thats why we can not use as a variable wheras eggs is a variable because it doesn't have any quotes on it. thats why it is valid.

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### Answer

# %% [markdown]
# for integer is int(). <br>
# floating- point number is float().<br>
# string version is string().<br>

# %%
# Out:
# <img src="data:image/png;base64,..."/>

# %%
'I have eaten' + 99 + 'burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-f5781a105d59> in <module>
# ----> 1 'I have eaten' + 99 + 'burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# This is **TypeError** because two different datatype can not be concatenate unless they have same datatype.<br>
# in this Expression 99 is interger whereas 'I have eaten' and 'burritos.' are string.<br>
# Therefor to concatenate the entire expression convert explicity 99 into string to perfor the expression valid.<br><br>
# This can be done by two ways:<br>
# - put single quote in 99 in the expression like 'I have eaten' + '99' + 'burritos.'
# - put str() function on 99 to convert from integer into string like 'I have eaten' + str(99) + 'burritos.'

# %%
'I have eaten' + '99' + 'burritos.'
# Out:
# 'I have eaten99burritos.'

# %%
 'I have eaten' + str(99) + 'burritos.'
# Out:
# 'I have eaten99burritos.'
